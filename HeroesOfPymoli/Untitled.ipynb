# %%
import pandas as pd
import os
path = os.path.join('Resources', 'zillow.csv')

# %%
zillow_df = pd.read_csv(path)
zillow_df.head()
# Out:
#    RegionID  SizeRank                          RegionName RegionType  \
# 0    102001         0                       United States    Country
# 1    394913         1                        New York, NY        Msa
# 2    753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 3    394463         3                         Chicago, IL        Msa
# 4    394514         4               Dallas-Fort Worth, TX        Msa
#
#   StateName  1996-01-31  1996-02-29  1996-03-31  1996-04-30  1996-05-31  ...  \
# 0       NaN    106657.0    106684.0    106734.0    106859.0    107001.0  ...
# 1        NY    188793.0    188352.0    188071.0    187536.0    187216.0  ...
# 2        CA    185661.0    185920.0    185940.0    186049.0    186022.0  ...
# 3        IL    161371.0    161075.0    160684.0    160239.0    159644.0  ...
# 4        TX    111730.0    111794.0    111953.0    112273.0    112617.0  ...
#
#    2019-06-30  2019-07-31  2019-08-31  2019-09-30  2019-10-31  2019-11-30  \
# ...

# %%
# create Series out of  RegionName column
regions = zillow_df['RegionName']
type(regions)
regions
# Out:
# 0                           United States
# 1                            New York, NY
# 2      Los Angeles-Long Beach-Anaheim, CA
# 3                             Chicago, IL
# 4                   Dallas-Fort Worth, TX
#                       ...
# 909                            Lamesa, TX
# 910                             Craig, CO
# 911                             Pecos, TX
# 912                            Vernon, TX
# 913                         Ketchikan, AK
# Name: RegionName, Length: 914, dtype: object

# %%
regions_n_state = zillow_df[['RegionName', 'RegionType']]
regions_n_state
# Out:
#                              RegionName RegionType
# 0                         United States    Country
# 1                          New York, NY        Msa
# 2    Los Angeles-Long Beach-Anaheim, CA        Msa
# 3                           Chicago, IL        Msa
# 4                 Dallas-Fort Worth, TX        Msa
# ..                                  ...        ...
# 909                          Lamesa, TX        Msa
# 910                           Craig, CO        Msa
# 911                           Pecos, TX        Msa
# 912                          Vernon, TX        Msa
# 913                       Ketchikan, AK        Msa
#
# [914 rows x 2 columns]

# %%
regions_dot_notation = zillow_df.RegionName
state_dot_notation = zillow_df.RegionType
state_dot_notation
zillow_df['Address'] = zillow_df.RegionName + ', ' + zillow_df.RegionType
zillow_df
# Out:
#      RegionID  SizeRank                          RegionName RegionType  \
# 0      102001         0                       United States    Country
# 1      394913         1                        New York, NY        Msa
# 2      753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 3      394463         3                         Chicago, IL        Msa
# 4      394514         4               Dallas-Fort Worth, TX        Msa
# ..        ...       ...                                 ...        ...
# 909    394767       929                          Lamesa, TX        Msa
# 910    753874       930                           Craig, CO        Msa
# 911    394968       931                           Pecos, TX        Msa
# 912    395188       932                          Vernon, TX        Msa
# 913    394743       933                       Ketchikan, AK        Msa
#
#     StateName  1996-01-31  1996-02-29  1996-03-31  1996-04-30  1996-05-31  \
# ...

# %%
zillow_tb = pd.read_table(path, sep=',')
zillow_tb.head()
# Out:
#    RegionID  SizeRank                          RegionName RegionType  \
# 0    102001         0                       United States    Country
# 1    394913         1                        New York, NY        Msa
# 2    753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 3    394463         3                         Chicago, IL        Msa
# 4    394514         4               Dallas-Fort Worth, TX        Msa
#
#   StateName  1996-01-31  1996-02-29  1996-03-31  1996-04-30  1996-05-31  ...  \
# 0       NaN    106657.0    106684.0    106734.0    106859.0    107001.0  ...
# 1        NY    188793.0    188352.0    188071.0    187536.0    187216.0  ...
# 2        CA    185661.0    185920.0    185940.0    186049.0    186022.0  ...
# 3        IL    161371.0    161075.0    160684.0    160239.0    159644.0  ...
# 4        TX    111730.0    111794.0    111953.0    112273.0    112617.0  ...
#
#    2019-06-30  2019-07-31  2019-08-31  2019-09-30  2019-10-31  2019-11-30  \
# ...

# %%
region_single_value = zillow_tb.loc[1, 'RegionName']
region_single_value
# Out:
# 'New York, NY'

# %%
regions_columns_multiple = zillow_tb.loc[1, ['RegionType', 'RegionName']]
regions_columns_multiple
# Out:
# RegionType             Msa
# RegionName    New York, NY
# Name: 1, dtype: object

# %%
rows_regionType_is_msa = zillow_tb.loc[zillow_tb.RegionType=='Msa', 'RegionType']
rows_regionType_is_msa
rows_regionType_is_msa_lenght = len(rows_regionType_is_msa)
rows_regionType_is_msa_lenght
# Out:
# 913
